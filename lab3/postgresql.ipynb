# %% [markdown]
# # install jupysql ให้ jupyter ใช้คำสั่งsql ได้ แล้วต่อกับ pgAdmin

# %%
# Install required packages
# % 1 ตัว = 1 บรรทัด
# %pip install jupysql psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load SQL extension

# %%
# %load_ext sql 

# Show more rows in results
# %config SqlMagic.displaylimit = 5 # 10rows
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ถ้าจะเปลี่ยนค่าให้ ใส่คำสั่ง %reload_ext sql

# %%
# %reload_ext sql

# %% [markdown]
# ## เชื่อมdatabase

# %%
# %sql postgresql://postgres:12345@localhost:5432/postgres
# Out:
# Connecting and switching to connection 'postgresql://postgres:***@localhost:5432/postgres'

# %%
# %sql SELECT version()
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 1 rows affected.
# +-------------------------------------------------------------------------+
# |                                 version                                 |
# +-------------------------------------------------------------------------+
# | PostgreSQL 18.1 on x86_64-windows, compiled by msvc-19.44.35221, 64-bit |
# +-------------------------------------------------------------------------+

# %%
# set search path
# %sql SET search_path TO classicmodels, public
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# ++
# ||
# ++
# ++

# %% [markdown]
# # เริ่ม คำสั่ง sql => query

# %%
# %%sql
# SELECT * FROM products
# WHERE productLine = 'Classic Cars'
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 38 rows affected.
# +-------------+--------------------------+--------------+-------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------+--------+--------------+
# | productcode |       productname        | productscale |      productvendor      |                                                                         productdescription                                                                        | quantityinstock | buyprice |  msrp  | productline  |
# +-------------+--------------------------+--------------+-------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------+--------+--------------+
# ...

# %%
# %%sql # % 2 ตัว = หลายบรรทัด
#
# SELECT contactLastName,
# salesRepEmployeeNumber
# FROM    classicmodels.customers
# where   salesRepEmployeeNumber
# 			in (1370 ,1501 ,1504 )
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 24 rows affected.
# +-----------------+------------------------+
# | contactlastname | salesrepemployeenumber |
# +-----------------+------------------------+
# |     Schmitt     |          1370          |
# |     Labrune     |          1370          |
# |    Bergulfsen   |          1504          |
# |      Keitel     |          1504          |
# |      Freyre     |          1370          |
# +-----------------+------------------------+
# Truncated to displaylimit of 5.
